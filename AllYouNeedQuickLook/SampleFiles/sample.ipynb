# %% [markdown]
# # Sample Notebook
#
# This notebook demonstrates **QuickLook** rendering of `.ipynb` files.
#
# Inline math: $E = mc^2$

# %%
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
print(f'Generated {len(x)} points')
# Out:
# Generated 100 points

# %%
# This cell shows an error output
result = 1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # This cell shows an error output
# ----> 2 result = 1 / 0
#
# ZeroDivisionError: division by zero

# %%
from IPython.display import HTML
HTML('<b>Bold HTML output</b>')
# Out:
# <b>Bold HTML output</b>

# %% [markdown]
# ## Block Math
#
# $$\int_{-\infty}^{\infty} e^{-x^2} dx = \sqrt{\pi}$$
