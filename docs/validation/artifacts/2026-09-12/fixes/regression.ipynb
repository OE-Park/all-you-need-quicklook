# %% [markdown]
# # Fixed notebook — September 12
#
# `a < b & c`
#
# <b>Raw HTML is bold.</b>
#
# ```sh
# echo '$HOME$'
# ```
#
# Math: $E=mc^2$
#
# Price $\text{price: \$5}$ and literal \$HOME\$.

# %%
print('visible output')
# Out:
# visible output
